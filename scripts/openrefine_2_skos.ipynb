# %% [markdown]
# # OpenRefine to SKOS
#
# Convert Export (tsv) of the enriched keywords to preliminary SKOS.

# %%
# !ls ../export
# Out:
# DHd-Affiliations.tsv

# %% [markdown]
# Use the export 2022-10-26: enriched in OpenRefine (could of course do more)...

# %%
refine_output_file = "../export/" + "DHd-Affiliations.tsv"

# %% [markdown]
# ## Table as pandas data frame

# %%
import pandas as pd

# %%
import numpy as np

# %%
#convert the tsv to a dataframe
df = pd.read_csv(refine_output_file, sep='\t', header=0)

# %%
df
# Out:
#                                            orig_string      country     city  \
# 0    Austrian Centre for Digital Humanities and Cul...   Österreich     Wien
# 1     Bayerische Akademie der Wissenschaftten, Germany  Deutschland  München
# 2                 Bayerische Staatsbibliothek, Germany  Deutschland  München
# 3    Berlin-Brandenburgische Akademie der Wissensch...  Deutschland   Berlin
# 4    Computational Humanities Group, Universität Le...  Deutschland  Leipzig
# ..                                                 ...          ...      ...
# 995  Wittgenstein-Archiv an der Universität Bergen,...     Norwegen   Bergen
# 996  Zentrum für Informationsmodellierung - Austria...   Österreich     Graz
# 997  Zentrum für Technologietransfer und Telekommun...  Deutschland    Worms
# 998  Zentrum Technik und Gesellschaft / TU Berlin, ...  Deutschland   Berlin
# 999               Ruhr-Universität-Bochum, Deutschland  Deutschland   Bochum
#
#     city_wd                      parent_institution_normalized  parent_type  \
# 0     Q1741        Österreichische Akademie der Wissenschaften     Akademie
# 1     Q1726             Bayerische Akademie der Wissenschaften     Akademie
# 2     Q1726                        Bayerische Staatsbibliothek   Bibliothek
# 3       Q64  Berlin-Brandenburgische Akademie der Wissensch...     Akademie
# 4     Q2079                                Universität Leipzig  Universität
# ..      ...                                                ...          ...
# 995  Q26793                                 Universität Bergen  Universität
# 996  Q13298                     Karl-Franzens-Universität Graz  Universität
# 997   Q3852                                           FH Worms  Universität
# 998     Q64                      Technische Universität Berlin  Universität
# 999   Q2103                            Ruhr-Universität Bochum  Universität
#
#     parent_wd                      parent_wikidata_uri  \
# 0     Q299015   http://www.wikidata.org/entity/Q299015
# 1     Q684415   http://www.wikidata.org/entity/Q684415
# 2     Q256507   http://www.wikidata.org/entity/Q256507
# 3     Q219989   http://www.wikidata.org/entity/Q219989
# 4     Q154804   http://www.wikidata.org/entity/Q154804
# ..        ...                                      ...
# 995   Q204457   http://www.wikidata.org/entity/Q204457
# 996   Q622683   http://www.wikidata.org/entity/Q622683
# 997  Q1391239  http://www.wikidata.org/entity/Q1391239
# 998    Q51985    http://www.wikidata.org/entity/Q51985
# 999   Q309948   http://www.wikidata.org/entity/Q309948
#
#                                         parent_reconci parent_factgrid  ...  \
# 0          Österreichische Akademie der Wissenschaften         Q399974  ...
# 1               Bayerische Akademie der Wissenschaften         Q164305  ...
# 2                          Bayerische Staatsbibliothek         Q153197  ...
# 3    Berlin-Brandenburgische Akademie der Wissensch...         Q230420  ...
# 4                                  Universität Leipzig          Q22261  ...
# ..                                                 ...             ...  ...
# 995                                 Universität Bergen             NaN  ...
# 996                                   Universität Graz         Q175366  ...
# 997                                   Hochschule Worms             NaN  ...
# 998                      Technische Universität Berlin         Q405632  ...
# 999                            Ruhr-Universität Bochum         Q398970  ...
#
#                parent_ROR_link parent_url  \
# 0    https://ror.org/03anc3s24        NaN
# 1    https://ror.org/001rdaz60        NaN
# 2    https://ror.org/031h71w90        NaN
# 3    https://ror.org/05jgq9443        NaN
# 4    https://ror.org/03s7gtk40        NaN
# ..                         ...        ...
# 995  https://ror.org/03zga2b32        NaN
# 996  https://ror.org/01faaaf77        NaN
# 997  https://ror.org/031ph8d53        NaN
# 998  https://ror.org/03v4gjf40        NaN
# 999  https://ror.org/04tsk2644        NaN
#
#                       institutional_subunit_normalized subunit_wd  \
# 0    Austrian Centre for Digital Humanities and Cul...  Q30268470
# 1                                                  NaN        NaN
# 2                                                  NaN        NaN
# 3                                                  NaN        NaN
# 4                                                  NaN        NaN
# ..                                                 ...        ...
# 995                                Wittgenstein Archiv        NaN
# 996  Zentrum für Informationsmodellierung - Austria...        NaN
# 997  Zentrum für Technologietransfer und Telekommun...        NaN
# 998                   Zentrum Technik und Gesellschaft        NaN
# 999                                                NaN        NaN
#
#                          subunit_wikidata_uri  \
# 0    http://www.wikidata.org/entity/Q30268470
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 995                                       NaN
# 996                                       NaN
# 997                                       NaN
# 998                                       NaN
# 999                                       NaN
#
#                                        subunit_reconci subunit_factgrid  \
# 0    Austrian Centre for Digital Humanities and Cul...              NaN
# 1                                                  NaN              NaN
# 2                                                  NaN              NaN
# 3                                                  NaN              NaN
# 4                                                  NaN              NaN
# ..                                                 ...              ...
# 995                                                NaN              NaN
# 996                                                NaN              NaN
# 997                                                NaN              NaN
# 998                                                NaN              NaN
# 999                                                NaN              NaN
#
#     subunit_ROR           subunit_ROR_link subunit_url
# 0     028bsh698  https://ror.org/028bsh698         NaN
# 1           NaN                        NaN         NaN
# 2           NaN                        NaN         NaN
# 3           NaN                        NaN         NaN
# 4           NaN                        NaN         NaN
# ..          ...                        ...         ...
# 995         NaN                        NaN         NaN
# 996         NaN                        NaN         NaN
# 997         NaN                        NaN         NaN
# 998         NaN                        NaN         NaN
# 999         NaN                        NaN         NaN
#
# [1000 rows x 21 columns]

# %%
unique_parent_orgs = df["parent_institution_normalized"].unique()

# %%
len(unique_parent_orgs)
# Out:
# 319

# %%
#Function to generate short hashes:
import hashlib
def shorthash(textstring:str):
    """
    Generate a trunctated md5 hash
    """
    hash = hashlib.sha1(textstring.encode("UTF-8")).hexdigest()
    shorthash = hash[:8]
    return shorthash

# %%
# set the baseuri for the new skos-terms:
baseuri = "https://dig-hum.de/vocabs/affiliations"

# %%
def label_to_uri(textstring:str):
    """
    Generate a uri with a short md5 hash
    """
    a_hash = shorthash(textstring.lower())
    uri = baseuri + "#" + a_hash
    return uri

# %%
label_to_uri("Universität zu Köln")
# Out:
# 'https://dig-hum.de/vocabs/affiliations#0f92bbab'

# %% [markdown]
# Testing how to interate and find rows:

# %%
unique_parent_orgs[11]
# Out:
# 'Fachhochschule Potsdam'

# %%
df.loc[df['parent_institution_normalized'] == unique_parent_orgs[11]]
# Out:
#                                            orig_string      country     city  \
# 13                     Fachhochschule Potsdam, Germany  Deutschland  Potsdam
# 14                       Fachhochschule Potsdam, UCLAB  Deutschland  Potsdam
# 16                             FH Potsdam, Deutschland  Deutschland  Potsdam
# 71              UCLAB, Fachhochschule Potsdam, Germany  Deutschland  Potsdam
# 125                Fachhochschule Potsdam, Deutschland  Deutschland  Potsdam
# 126  Fachhochschule Potsdam, Fachbereich Informatio...  Deutschland  Potsdam
# 127                             Fachhochschule Potsdam  Deutschland  Potsdam
# 227         UCLAB, Fachhochschule Potsdam, Deutschland  Deutschland  Potsdam
# 229                                         FH Potsdam  Deutschland  Potsdam
# 403            University of Appliend Sciences Potsdam  Deutschland  Potsdam
# 404  Urban Complexity Lab, Fachhochschule Potsdam, ...  Deutschland  Potsdam
# 521  Fachbereich Informationswissenschaften, Fachho...  Deutschland  Potsdam
#
#     city_wd parent_institution_normalized     parent_type parent_wd  \
# 13    Q1711        Fachhochschule Potsdam  Fachhochschule   Q896706
# 14    Q1711        Fachhochschule Potsdam  Fachhochschule   Q896706
# 16    Q1711        Fachhochschule Potsdam  Fachhochschule   Q896706
# 71    Q1711        Fachhochschule Potsdam  Fachhochschule   Q896706
# 125   Q1711        Fachhochschule Potsdam  Fachhochschule   Q896706
# 126   Q1711        Fachhochschule Potsdam  Fachhochschule   Q896706
# 127   Q1711        Fachhochschule Potsdam  Fachhochschule   Q896706
# 227   Q1711        Fachhochschule Potsdam  Fachhochschule   Q896706
# 229   Q1711        Fachhochschule Potsdam  Fachhochschule   Q896706
# 403   Q1711        Fachhochschule Potsdam  Fachhochschule   Q896706
# 404   Q1711        Fachhochschule Potsdam  Fachhochschule   Q896706
# 521   Q1711        Fachhochschule Potsdam  Fachhochschule   Q896706
#
#                         parent_wikidata_uri          parent_reconci  \
# 13   http://www.wikidata.org/entity/Q896706  Fachhochschule Potsdam
# 14   http://www.wikidata.org/entity/Q896706  Fachhochschule Potsdam
# 16   http://www.wikidata.org/entity/Q896706  Fachhochschule Potsdam
# 71   http://www.wikidata.org/entity/Q896706  Fachhochschule Potsdam
# 125  http://www.wikidata.org/entity/Q896706  Fachhochschule Potsdam
# 126  http://www.wikidata.org/entity/Q896706  Fachhochschule Potsdam
# 127  http://www.wikidata.org/entity/Q896706  Fachhochschule Potsdam
# 227  http://www.wikidata.org/entity/Q896706  Fachhochschule Potsdam
# 229  http://www.wikidata.org/entity/Q896706  Fachhochschule Potsdam
# 403  http://www.wikidata.org/entity/Q896706  Fachhochschule Potsdam
# 404  http://www.wikidata.org/entity/Q896706  Fachhochschule Potsdam
# 521  http://www.wikidata.org/entity/Q896706  Fachhochschule Potsdam
#
#     parent_factgrid  ...            parent_ROR_link parent_url  \
# 13              NaN  ...  https://ror.org/012m9bp23        NaN
# 14              NaN  ...  https://ror.org/012m9bp23        NaN
# 16              NaN  ...  https://ror.org/012m9bp23        NaN
# 71              NaN  ...  https://ror.org/012m9bp23        NaN
# 125             NaN  ...  https://ror.org/012m9bp23        NaN
# 126             NaN  ...  https://ror.org/012m9bp23        NaN
# 127             NaN  ...  https://ror.org/012m9bp23        NaN
# 227             NaN  ...  https://ror.org/012m9bp23        NaN
# 229             NaN  ...  https://ror.org/012m9bp23        NaN
# 403             NaN  ...  https://ror.org/012m9bp23        NaN
# 404             NaN  ...  https://ror.org/012m9bp23        NaN
# 521             NaN  ...  https://ror.org/012m9bp23        NaN
#
#            institutional_subunit_normalized subunit_wd subunit_wikidata_uri  \
# 13                                      NaN        NaN                  NaN
# 14                                      NaN        NaN                  NaN
# 16                                      NaN        NaN                  NaN
# 71                                      NaN        NaN                  NaN
# 125                                     NaN        NaN                  NaN
# 126                                     NaN        NaN                  NaN
# 127                                     NaN        NaN                  NaN
# 227                                     NaN        NaN                  NaN
# 229                                     NaN        NaN                  NaN
# 403                                     NaN        NaN                  NaN
# 404                                     NaN        NaN                  NaN
# 521  Fachbereich Informationswissenschaften        NaN                  NaN
#
#     subunit_reconci subunit_factgrid subunit_ROR subunit_ROR_link subunit_url
# 13              NaN              NaN         NaN              NaN         NaN
# 14              NaN              NaN         NaN              NaN         NaN
# 16              NaN              NaN         NaN              NaN         NaN
# 71              NaN              NaN         NaN              NaN         NaN
# 125             NaN              NaN         NaN              NaN         NaN
# 126             NaN              NaN         NaN              NaN         NaN
# 127             NaN              NaN         NaN              NaN         NaN
# 227             NaN              NaN         NaN              NaN         NaN
# 229             NaN              NaN         NaN              NaN         NaN
# 403             NaN              NaN         NaN              NaN         NaN
# 404             NaN              NaN         NaN              NaN         NaN
# 521             NaN              NaN         NaN              NaN         NaN
#
# [12 rows x 21 columns]

# %%
# get distinct labels
df.loc[df['parent_institution_normalized'] == unique_parent_orgs[11]]["orig_string"].unique()
# Out:
# array(['Fachhochschule Potsdam, Germany', 'Fachhochschule Potsdam, UCLAB',
#        'FH Potsdam, Deutschland',
#        'UCLAB, Fachhochschule Potsdam, Germany',
#        'Fachhochschule Potsdam, Deutschland',
#        'Fachhochschule Potsdam, Fachbereich Informationswissenschaften, RDMO, Deutschland',
#        'Fachhochschule Potsdam',
#        'UCLAB, Fachhochschule Potsdam, Deutschland', 'FH Potsdam',
#        'University of Appliend Sciences Potsdam',
#        'Urban Complexity Lab, Fachhochschule Potsdam, Deutschland',
#        'Fachbereich Informationswissenschaften, Fachhochschule Potsdam, Deutschland'],
#       dtype=object)

# %%
#get subunits
df.loc[df['parent_institution_normalized'] == unique_parent_orgs[11]]["institutional_subunit_normalized"].unique()
# Out:
# array([nan, 'Fachbereich Informationswissenschaften'], dtype=object)

# %% [markdown]
# ## Some notes on modeling the keywords in SKOS

# %% [markdown]
# From the [SKOS Primer](https://www.w3.org/TR/2009/NOTE-skos-primer-20090818/#secalt):
#
# `skos:prefLabel "animals"@en;`
#
# `skos:altLabel "creatures"@en;`
#
# also use:
# > A hidden lexical label, represented by means of the skos:hiddenLabel property, is a lexical label for a resource, where a KOS designer would like that character string to be accessible to applications performing text-based indexing and search operations, but would not like that label to be visible otherwise. Hidden labels may for instance be used to include misspelled variants of other lexical labels. For example:
#
# `skos:hiddenLabel "betes"@fr.`
#
# e.g.:
# ```
# skos:prefLabel "Authorship attribution" ;
# skos:hiddenLabel "authorship attibution" ;
# ```

# %% [markdown]
# Semantic Links:
#
# > `skos:broader` and `skos:narrower` enable the representation of hierarchical links, such as the relationship between one genre and its more specific species, or, depending on interpretations, the relationship between one whole and its parts;
# > `skos:related` enables the representation of associative (non-hierarchical) links, such as the relationship between one type of event and a category of entities which typically participate in it. Another use for skos:related is between two categories where neither is more general or more specific. Note that skos:related enables the representation of associative (non-hierarchical) links, which can also be used to represent part-whole links that are not meant as hierarchical relationships.

# %% [markdown]
# owl:sameAs vs. skos:exactMatch:
# > Note on `skos:exactMatch` vs. `owl:sameAs`: SKOS provides `skos:exactMatch` to map concepts with equivalent meaning, and intentionally does not use owl:sameAs from the OWL ontology language [OWL]. When two resources are linked with `owl:sameAs` they are considered to be the same resource, and triples involving these resources are merged. This does not fit what is needed in most SKOS applications.

# %% [markdown]
# ## Transform keyword into a SKOS concept
# I will do some testing and then come up with a function to transform the keywords based on `unique_clustered_terms`.

# %%
import rdflib

# %%
from rdflib import Namespace, URIRef, RDF, RDFS, Literal, Graph, XSD, SKOS, DCTERMS, DC

# %%
def add_ns(graph):
    graph.bind("skos", SKOS)
    graph.bind("dcterms", DCTERMS)
    graph.bind("dc", DC)
    return graph

# %%
#setup the concept scheme
vocab_g = rdflib.Graph()
VOCAB = URIRef(baseuri)
vocab_g.add(( VOCAB, RDF.type, SKOS.ConceptScheme ))
vocab_g.add(( VOCAB, SKOS.prefLabel, Literal("DHd Institutionszugehörigkeiten", lang="de") ))
vocab_g.add(( VOCAB, SKOS.prefLabel, Literal("DHd Affiliations", lang="en") ))

# add documentation in Dublin Core (dct vs. dc elements?)
vocab_g.add(( VOCAB, DC.title, Literal("DHd Institutionszugehörigkeiten", lang="de") ))
vocab_g.add(( VOCAB, DC.title, Literal("DHd Affiliations", lang="en") ))

vocab_g.add(( VOCAB, DC.creator, Literal("Ingo Börner") ))
vocab_g.add(( VOCAB, DC.contributor, Literal("TF DHd Abstracts") ))
vocab_g.add(( VOCAB, DC.date, Literal("2022") ))
vocab_g.add((VOCAB, DC.relation,  URIRef("https://zenodo.org/communities/dhd")))

# ...

print(vocab_g.serialize(format="ttl"))
# Out:
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
#
# <https://dig-hum.de/vocabs/affiliations> a skos:ConceptScheme ;
#     dc:contributor "TF DHd Abstracts" ;
#     dc:creator "Ingo Börner" ;
#     dc:date "2022" ;
#     dc:relation <https://zenodo.org/communities/dhd> ;
#     dc:title "DHd Institutionszugehörigkeiten"@de,
#         "DHd Affiliations"@en ;
#     skos:prefLabel "DHd Institutionszugehörigkeiten"@de,
#         "DHd Affiliations"@en .

# %%
def type_to_collection_uri(type_string:str):
    """
    Generate a URI from a type label
    """
    type_str_clean = type_string.lower().replace("ö","oe").replace("ä","ae").replace("ü","ue").replace(" ","_")
    uri = baseuri + "#" + type_str_clean + "_collection"
    return uri

# %%
type_to_collection_uri("Universität")
# Out:
# 'https://dig-hum.de/vocabs/affiliations#universitaet_collection'

# %%
def affiliation_as_concept(normalized_label:str):
    """
    Generates a skosConcept of an affiliation; uses "parent_institution_normalized" as input "normalized_label"
    """
    g = rdflib.Graph()
    g = add_ns(g)
    
    #get the data from the dataframe df
    data = df.loc[df['parent_institution_normalized'] == normalized_label]
    
    #generate an URI
    uri = label_to_uri(normalized_label)
    CONCEPT = URIRef(uri)
    #add the concept to the graph
    g.add(( CONCEPT, RDF.type, SKOS.Concept))
    
    #use normalized label as skos:prefLabel
    #maybe have to add a language tag consequently to the graph and edit where necessary?
    #for now I just assume, it's german.. Oh no..
    g.add(( CONCEPT, SKOS.prefLabel, Literal(normalized_label, lang="de")))
    
    #wd link
    for wd_uri in data["parent_wikidata_uri"].unique():
        if str( wd_uri) != "nan":
            g.add(( CONCEPT, SKOS.exactMatch, URIRef(wd_uri) ))
            
    #ROR
    for ror_uri in data["parent_ROR_link"].unique():
        if str( ror_uri) != "nan":
            g.add(( CONCEPT, SKOS.exactMatch, URIRef(ror_uri) ))
    
    #factgrid
    #should add, but need URI scheme
    
    #hidden labels, need all rows that are not subunits
    parent_rows_vanilla = data[data['institutional_subunit_normalized'].isna()]
    #print(parent_rows_vanilla)
    for parent_hidden_label in parent_rows_vanilla["orig_string"].unique():
        g.add(( CONCEPT, SKOS.hiddenLabel, Literal(parent_hidden_label) ))
    
    #maybe add the reconciled label as altLabel
    for reconci_label in data["parent_reconci"].unique():
        if str( reconci_label) != "nan":
            if reconci_label != normalized_label:
                g.add(( CONCEPT, SKOS.altLabel, Literal(reconci_label, lang="de") ))
    
    
    
    #get the unique subunits:
    subunits = []
    unique_subunits_strings = data["institutional_subunit_normalized"].unique()
    for subunit_str in unique_subunits_strings:
        if str(subunit_str) != "nan":
            subunit = {}
            subunit["label"] = subunit_str
            subunit["full_label"] = normalized_label + " / " + subunit_str
            subunit["uri"] = label_to_uri(subunit["full_label"])
            subunits.append(subunit)
    
    #print(subunits)
    for subunit_item in subunits:
        subunit_data = df.loc[df['institutional_subunit_normalized'] == subunit_item["label"]]
        SUBUNIT = URIRef(subunit_item["uri"])
        g.add(( SUBUNIT, RDF.type, SKOS.Concept ))
        g.add(( SUBUNIT, SKOS.prefLabel, Literal(subunit_item["label"], lang="de")  ))
        g.add(( SUBUNIT, SKOS.altLabel, Literal(subunit_item["full_label"], lang="de")  ))
        #broader, narrower
        g.add(( SUBUNIT, SKOS.broader, CONCEPT ))
        g.add(( CONCEPT, SKOS.narrower, SUBUNIT))
        
        #wd links, ROR links, hidden labels
        
        #wd link
        for sub_wd_uri in subunit_data["subunit_wikidata_uri"].unique():
            if str( sub_wd_uri) != "nan":
                g.add(( SUBUNIT, SKOS.exactMatch, URIRef(sub_wd_uri) ))
            
        #ROR
        for sub_ror_uri in data["subunit_ROR_link"].unique():
            if str( sub_ror_uri) != "nan":
                g.add(( SUBUNIT, SKOS.exactMatch, URIRef(sub_ror_uri) ))
        
        #hidden labels
        for subunit_hidden_label in subunit_data["orig_string"].unique():
            g.add(( SUBUNIT, SKOS.hiddenLabel, Literal(subunit_hidden_label) ))
        
        
        #add to vocab
        g.add(( SUBUNIT, SKOS.inScheme, VOCAB))
        
    
    # the Collections
    # use the type as Group; group by city and country
    for parent_type in data["parent_type"].unique():
        if str(parent_type) != "nan":
            #function to translate type strings to uris:
            group_uri = type_to_collection_uri(parent_type)
            g.add(( URIRef(group_uri), RDF.type, SKOS.Collection ))
            g.add(( URIRef(group_uri), SKOS.prefLabel, Literal(parent_type, lang="de") ))
            g.add(( URIRef(group_uri), SKOS.member, CONCEPT ))
            
    #Stadt
    for parent_city in data["city"].unique():
        if str(parent_city) != "nan":
            city_group_uri = type_to_collection_uri(parent_city)
            g.add(( URIRef(city_group_uri), RDF.type, SKOS.Collection ))
            g.add(( URIRef(city_group_uri), SKOS.prefLabel, Literal(parent_city, lang="de") ))
            g.add(( URIRef(city_group_uri), SKOS.member, CONCEPT ))
    
    
    
    
    #need to "hook" to concept scheme
    g.add(( CONCEPT, SKOS.inScheme, VOCAB))
    # add this as a top concept
    #skos:topConceptOf
    g.add((CONCEPT, SKOS.topConceptOf, VOCAB ))
    g.add(( VOCAB, SKOS.hasTopConcept, CONCEPT ))
    
    return g

# %%
test_label = "Universität zu Köln"
test_concept_g = affiliation_as_concept(test_label)

# %%
print(test_concept_g.serialize(format="ttl"))
# Out:
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
#
# <https://dig-hum.de/vocabs/affiliations#koeln_collection> a skos:Collection ;
#     skos:member <https://dig-hum.de/vocabs/affiliations#0f92bbab> ;
#     skos:prefLabel "Köln"@de .
#
# <https://dig-hum.de/vocabs/affiliations#universitaet_collection> a skos:Collection ;
#     skos:member <https://dig-hum.de/vocabs/affiliations#0f92bbab> ;
#     skos:prefLabel "Universität"@de .
#
# <https://dig-hum.de/vocabs/affiliations#47f4bc6a> a skos:Concept ;
#     skos:altLabel "Universität zu Köln / Institut für Medienkultur und Theater"@de ;
#     skos:broader <https://dig-hum.de/vocabs/affiliations#0f92bbab> ;
#     skos:exactMatch <http://www.wikidata.org/entity/Q101248538> ;
#     skos:hiddenLabel "Institut für Medienkultur und Theater" ;
#     skos:inScheme <https://dig-hum.de/vocabs/affiliations> ;
#     skos:prefLabel "Institut für Medienkultur und Theater"@de .
#
# <https://dig-hum.de/vocabs/affiliations#5939e6fc> a skos:Concept ;
#     skos:altLabel "Universität zu Köln / Data Center for the Humanites"@de ;
#     skos:broader <https://dig-hum.de/vocabs/affiliations#0f92bbab> ;
#     skos:hiddenLabel "Data Center for the Humanites (DCH), Universität zu Köln, Deutschland",
#         "Data Center for the Humanities (DCH), Universität zu Köln",
#         "Data Center for the Humanities (DCH), Universität zu Köln, Deutschland",
#         "Data Center for the Humanities, Universität zu Köln",
#         "Data Center for the Humanities, Universität zu Köln, Deutschland",
#         "Universität zu Köln, Data Center for the Humanities (DCH)" ;
#     skos:inScheme <https://dig-hum.de/vocabs/affiliations> ;
#     skos:prefLabel "Data Center for the Humanites"@de .
#
# <https://dig-hum.de/vocabs/affiliations#639a6aaa> a skos:Concept ;
#     skos:altLabel "Universität zu Köln / Theaterwissenschaftliche Sammlung"@de ;
#     skos:broader <https://dig-hum.de/vocabs/affiliations#0f92bbab> ;
#     skos:exactMatch <http://www.wikidata.org/entity/Q2416312> ;
#     skos:hiddenLabel "Theaterwissenschaftliche Sammlung der Universität zu Köln" ;
#     skos:inScheme <https://dig-hum.de/vocabs/affiliations> ;
#     skos:prefLabel "Theaterwissenschaftliche Sammlung"@de .
#
# <https://dig-hum.de/vocabs/affiliations#69e63fae> a skos:Concept ;
#     skos:altLabel "Universität zu Köln / Musikwissenschaftliches Institut"@de ;
#     skos:broader <https://dig-hum.de/vocabs/affiliations#0f92bbab> ;
#     skos:exactMatch <http://www.wikidata.org/entity/Q101248555> ;
#     skos:hiddenLabel "Musikwissenschaftliches Institut, Universität zu Köln" ;
#     skos:inScheme <https://dig-hum.de/vocabs/affiliations> ;
#     skos:prefLabel "Musikwissenschaftliches Institut"@de .
#
# <https://dig-hum.de/vocabs/affiliations#80365587> a skos:Concept ;
#     skos:altLabel "Universität zu Köln / Cologne Center for eHumanities"@de ;
#     skos:broader <https://dig-hum.de/vocabs/affiliations#0f92bbab> ;
#     skos:hiddenLabel "CCeH, Universität Köln, Deutschland",
#         "Cologne Center for eHumanities",
#         "Cologne Center for eHumanities (CCeH), Germany",
#         "Cologne Center for eHumanities (CCeH), Universität zu Köln, Deutschland",
#         "Cologne Center for eHumanities, Universität zu Köln",
#         "Cologne Center for eHumanities, Universität zu Köln, Deutschland",
#         "Universität zu Köln, Cologne Center for eHumanities",
#         "Universität zu Köln, Cologne Center for eHumanities (CCeH)",
#         "Universität zu Köln/CCeH" ;
#     skos:inScheme <https://dig-hum.de/vocabs/affiliations> ;
#     skos:prefLabel "Cologne Center for eHumanities"@de .
#
# <https://dig-hum.de/vocabs/affiliations#9cda71e1> a skos:Concept ;
#     skos:altLabel "Universität zu Köln / Kunsthistorisches Institut"@de ;
#     skos:broader <https://dig-hum.de/vocabs/affiliations#0f92bbab> ;
#     skos:hiddenLabel "Universität zu Köln, Kunsthistorisches Institut" ;
#     skos:inScheme <https://dig-hum.de/vocabs/affiliations> ;
#     skos:prefLabel "Kunsthistorisches Institut"@de .
#
# <https://dig-hum.de/vocabs/affiliations#d441fdb8> a skos:Concept ;
#     skos:altLabel "Universität zu Köln / Historisch-Kulturwissenschaftliche Informationsverarbeitung"@de ;
#     skos:broader <https://dig-hum.de/vocabs/affiliations#0f92bbab> ;
#     skos:hiddenLabel "Universität Köln, Historisch-Kulturwissenschaftliche Informationsverarbeitung" ;
#     skos:inScheme <https://dig-hum.de/vocabs/affiliations> ;
#     skos:prefLabel "Historisch-Kulturwissenschaftliche Informationsverarbeitung"@de .
#
# <https://dig-hum.de/vocabs/affiliations#f15b7642> a skos:Concept ;
#     skos:altLabel "Universität zu Köln / Institut für Digital Humanities"@de ;
#     skos:broader <https://dig-hum.de/vocabs/affiliations#0f92bbab> ;
#     skos:hiddenLabel "Institut für Digital Humanities, Universität zu Köln, Deutschland",
#         "Universität zu Köln, Institut für Digital Humanities (IDH)" ;
#     skos:inScheme <https://dig-hum.de/vocabs/affiliations> ;
#     skos:prefLabel "Institut für Digital Humanities"@de .
#
# <https://dig-hum.de/vocabs/affiliations#f3082730> a skos:Concept ;
#     skos:altLabel "Universität zu Köln / Institut für Linguistik"@de ;
#     skos:broader <https://dig-hum.de/vocabs/affiliations#0f92bbab> ;
#     skos:exactMatch <http://www.wikidata.org/entity/Q101248536> ;
#     skos:hiddenLabel "Institut für Linguistik, Universität zu Köln" ;
#     skos:inScheme <https://dig-hum.de/vocabs/affiliations> ;
#     skos:prefLabel "Institut für Linguistik"@de .
#
# <https://dig-hum.de/vocabs/affiliations> skos:hasTopConcept <https://dig-hum.de/vocabs/affiliations#0f92bbab> .
#
# <https://dig-hum.de/vocabs/affiliations#0f92bbab> a skos:Concept ;
#     skos:exactMatch <http://www.wikidata.org/entity/Q54096>,
#         <https://ror.org/00rcxh774> ;
#     skos:hiddenLabel "Universität Köln, Deutschland",
#         "Universität Köln, Germany",
#         "Universität zu Köln",
#         "Universität zu Köln, Data Center for the Humanities (DCH); Universität zu Köln, Institut für Linguistik (IfL)",
#         "Universität zu Köln, Deutschland",
#         "Universität zu Köln, Germany" ;
#     skos:inScheme <https://dig-hum.de/vocabs/affiliations> ;
#     skos:narrower <https://dig-hum.de/vocabs/affiliations#47f4bc6a>,
#         <https://dig-hum.de/vocabs/affiliations#5939e6fc>,
#         <https://dig-hum.de/vocabs/affiliations#639a6aaa>,
#         <https://dig-hum.de/vocabs/affiliations#69e63fae>,
#         <https://dig-hum.de/vocabs/affiliations#80365587>,
#         <https://dig-hum.de/vocabs/affiliations#9cda71e1>,
#         <https://dig-hum.de/vocabs/affiliations#d441fdb8>,
#         <https://dig-hum.de/vocabs/affiliations#f15b7642>,
#         <https://dig-hum.de/vocabs/affiliations#f3082730> ;
#     skos:prefLabel "Universität zu Köln"@de ;
#     skos:topConceptOf <https://dig-hum.de/vocabs/affiliations> .

# %%
# %%time
#join everything
the_whole_g = rdflib.Graph()
the_whole_g = add_ns(the_whole_g)
the_whole_g = the_whole_g + vocab_g
#add the single concept in a for-loop
for aff in unique_parent_orgs:
    if str(aff) != "nan":
        concept_g = affiliation_as_concept(aff)
        the_whole_g = the_whole_g + concept_g
# Out:
# CPU times: user 11.5 s, sys: 67.6 ms, total: 11.6 s
# Wall time: 11.6 s

# %% [markdown]
# ## Validation of the SKOS

# %%
#!pip install skosify

# %%
import skosify

# %%
voc = skosify.skosify(the_whole_g)
# Out:
# WARNING:root:Resource https://dig-hum.de/vocabs/affiliations#3d1b5e9a has more than one prefLabel@de: choosing Institut für Maschinelle Sprachverarbeitung (policy: shortest)

# %%
#messes up the namespaces, which I have to override after cleaning up
#voc.bind('crm', CRM, override=True)
#voc.bind('custom', CUSTOM, override=True)

# %%
#store the whole graph
voc.serialize(destination="../export/DHd-Affiliations.ttl", format="turtle")
# Out:
# <Graph identifier=N6693a4bc52104b0fa6142ad5d23db64f (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ## Visualize in Skosmos
# I set up a skosmos instance using the docker-compose provided by skosmos here: https://github.com/NatLibFi/Skosmos
#
# Updated skosmos: `conig-docker-compose.ttl` in `dockerfiles`
#
# ```
# :affiliations a skosmos:Vocabulary, void:Dataset ;
#     dc:title "DHd Affiliations"@en ;
#     dc:title "DHd Institutionszugehörigkeiten"@de ;
#     skosmos:shortName "dhd-affiliations";
#     dc:subject :cat_general ;
#     void:uriSpace "https://dig-hum.de/vocabs/affiliations#";
#     skosmos:language "de";
#     skosmos:defaultLanguage "de";
#     skosmos:showTopConcepts true ;
#     skosmos:fullAlphabeticalIndex true ;
#     skosmos:groupClass skos:Collection ;
#     void:sparqlEndpoint <http://fuseki-cache:80/skosmos/sparql> ;
#     skosmos:sparqlGraph <https://dig-hum.de/vocabs/affiliations> .
# ````
# To load data:
#
# `curl -I -X POST -H Content-Type:text/turtle -T DHd-Affiliations.ttl -G http://localhost:9030/skosmos/data --data-urlencode graph=https://dig-hum.de/vocabs/affiliations`
